# %%
#run this cell once
# %matplotlib notebook

# %%
# run this cell once
import importlib
import lib
importlib.reload(lib)
from lib import *

# %% [markdown]
# # Assignment 3

# %% [markdown]
# prerequisites :
# - basic understanding of Jupyter notebooks (https://jupyter.org/)
# - basic understanding of binder (https://mybinder.org/)
# - GitHub account (https://github.com/)<br><br>
# Resources
# - understanding the 'range' function (https://www.w3schools.com/python/ref_func_range.asp)
# - understanding the 'while' loop (https://www.w3schools.com/python/python_while_loops.asp)
# - understanding of the 'if' statement  (https://www.w3schools.com/python/python_conditions.asp)
# - understanding of 'functions' https://www.w3schools.com/python/python_functions.asp
# - A walkthrough of some of the important <a href="https://codeinplace2021.github.io/pythonreader/en/variables/">data types and python operators  </a>

# %%
#run this cell once and also everytime when resetting the grid. 
import importlib
import lib
importlib.reload(lib)
from lib import *
token_loc=[[2,3,2,3]]
Ghotul=None
Ghotul=bot(token_loc,20,20)
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %% [markdown]
# # Functions
# Functions enable decomposition of code into sub tasks that usually repeat . This makes the code easier to handle and debug. A function defintion starts with a keyword 'def' , a function name and optionally arguments or parameters that can be passed to the function.A function can be called from anywhere in the code by specifying the function name along with the arguments that it takes.Indentation is important while writing a function definition.The argument variables and any other variables declared in the function are local in scope to the function i.e. they do not retain their values outside of the function. A function may return a value to the variable from which it is being called.

# %%
# Here is an example of a function definition and call
def multiply(x,y):
    return x*y

print("Product of 7 and 5 is",multiply(7,5))

# %%
# Here is an example of a function definition and call
#this function turns Ghotul in the opposite direction to where it was facing, observe this on the Grid above
def about_turn():
    Ghotul.turn_left()
    Ghotul.turn_left()
#this function moves Ghotul the number of paces specified in the argument , Note the indentation syntax,observe this on the Grid above
def move_paces(paces):
    for i in range(paces):
        Ghotul.move()
        
        
move_paces(2)    #moving Ghotul 2 paces, experiment with a different number
about_turn()     #turn around Ghotul

# %% [markdown]
# Arrange the eggs along a slope . i.e. finall output should look like this
# ![image.png](attachment:image.png)

# %% [markdown]
# Here are a list of  commands that can be used:

# %% [markdown]
# The main character of this story is this funny looking dog-like creature called 'Ghotul'
# ![image.png](attachment:image.png)

# %% [markdown]
# The eggs are these objects
# ![image.png](attachment:image.png)

# %% [markdown]
# 'Ghotul' can perform the following actions
# - Ghotul.move() : Moves 1 step in the direction it is facing.
# - Ghotul.turn_left() : Turns left in the same location as it is currently in.
# - Ghotul.pick_egg() : Ghotul picks up an egg provided it is on the location where the egg is.
# - Ghotul.drop_egg()  : Ghotul drops an egg at the location it is currently located at.

# %% [markdown]
# The following conditions can be used for moving Ghotul around
# - Ghotul.right_wall() : checks if Ghotul has reached  the right wall of the grid
# - Ghotul.left_wall()  :  checks if Ghotul has reached the left wall of the grid
# - Ghotul.bottom_wall() : checks if Ghotul has reached the bottom wall of the grid
# - Ghotul.top_wall() : checks if Ghotul has reached the top wall of the grid
# - Ghotul.front_is_clear() : checks if front is clear of eggs or a boundary wall

# %%
#start your code from here , you can add code in additional cells if necessary
