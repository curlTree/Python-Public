# %%
# %matplotlib notebook

# %% [markdown]
# https://pythontic.com/image-processing/pillow/rotate
# https://realpython.com/python-sleep/
# https://www.tutorialspoint.com/matplotlib/matplotlib_setting_ticks_and_tick_labels.htm

# %%
from lib import *
plt.cla()

# %%
token_loc=[[2,3,2,3],[4,5,3,4], [3,4,3,4]]
cbot=None
cbot=bot(token_loc)
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
cbot.move()

# %%
cbot.move()
cbot.turn_left()
cbot.move()
cbot.move()
cbot.turn_left()
cbot.turn_left()
cbot.turn_left()
cbot.move()
cbot.move()

# %%
cbot.pick_token()

# %%
cbot.move()

# %%
cbot.drop_token()

# %%
cbot.turn_left()
