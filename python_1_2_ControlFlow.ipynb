# %%
#run this cell once
# %matplotlib notebook

# %%
#run this cell once
import importlib
import lib
importlib.reload(lib)
from lib import *

# %% [markdown]
# # Assignment 2

# %% [markdown]
#     Prerequisites
# - basic understanding of Jupyter notebooks (https://jupyter.org/)
# - basic understanding of binder (https://mybinder.org/)
# - GitHub account (https://github.com/)<br><br>
#    Resources:<br>
# - understanding the 'range' function (https://www.w3schools.com/python/ref_func_range.asp)
# - understanding the 'while' loop (https://www.w3schools.com/python/python_while_loops.asp)
# - understanding of the 'for' loop  (https://www.w3schools.com/python/python_for_loops.asp)
# - understanding of the 'if' statement  (https://www.w3schools.com/python/python_conditions.asp)
# - A walkthrough of some of the important <a href="https://codeinplace2021.github.io/pythonreader/en/variables/">data types and python operators  </a>

# %%
#run this cell once and also everytime when resetting the grid. 
import importlib
import lib
importlib.reload(lib)
from lib import *

token_loc=[[2,3,0,1],[2,3,2,3], [2,3,6,7],[2,3,8,9],[2,3,10,11],
          [5,6,0,1],[5,6,2,3],[5,6,4,5], [5,6,6,7],[5,6,10,11],
          [8,9,0,1],[8,9,4,5], [8,9,6,7],[8,9,8,9],[8,9,10,11],
          [11,12,0,1],[11,12,2,3],[11,12,4,5], [11,12,6,7],[11,12,10,11]]
Ghotul=None
Ghotul=bot(token_loc,20,20)
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %% [markdown]
# # The 'print()' function.
# The 'print()' function displays output as text and is useful for showing results of calculations as well as for debugging code. Text should be within  "" and numeric values when being shown concatenated with text need to be cast to string.

# %%
# Here is an example of the print statement
print("Hello World")
print("The sum of 2 and 3 is ",2+3)
print("The sum of 2 and 3 is " + str(2+3))
print("The sum of 2 and 3 is =",str(2+3))
print("The sum of 2 and 3 is", "= " + str(2+3) +" units")

# %% [markdown]
# # The 'if' Statement
# The 'if, elif, else' statement is a conditional statement and executes specific pieces of code depending on the condition evaluating to True or False.The 'if' statement exits after the executing the first statement that evaluates to being True.

# %%
#Here is an example
if (5>3):
    print("5 greater than 3")
else:
    print("5 is less than or equal to 3")

if (7<5):
    print("7 is greater or equal than 5")
else:
    print("7 is less than 5")

# %% [markdown]
# # The 'while' loop
# The 'while' loop repeats a piece of code as long as the 'while' condition holds True. It exits  when the condition is False.
# Care must be taken while writing a 'while' loop that it has a terminating condition else it may loop infinitely.

# %%
# Here is an example of 'while' loop which moves Ghotul on the grid as long as front is clear
while Ghotul.front_is_clear():
    Ghotul.move()

# %% [markdown]
# # The Range function
# The range function generates a sequence of numbers that can be used in loops or as an index. It takes upto 3 arguments
# , the starting number, the ending number and the increment step size.
# The Range sequence takes values upto but not including the ending number.

# %%
#Here is an example of the Range function
print (range(4))
print (range(1,4,1))
print (range(-1,4,1))

# %% [markdown]
# # The 'for' loop
# The 'for' loop is similar to the 'while' loop , the main difference being that the number of iterations of the loop needs to be known in advance. It is a safer option when the number of times we want the loop to execute is already known. This prevents a situation of 'infinite loop' from arising.

# %%
# Here is an example of 'for' loop which moves Ghotul 4 steps in the direction it is facing
#Here i takes each value from the sequence one at a time i.e 0,1,2,3 in this case. Note when not specified, the sequence starts from 0
for i in range(4):
    Ghotul.move()

# %% [markdown]
# Replace  the missing eggs in the columns. i.e. final output should look like this
# ![image.png](attachment:image.png)

# %% [markdown]
# Here are a list of  commands that can be used:

# %% [markdown]
# The main character of this story is this funny looking dog-like creature called 'Ghotul'
# ![image.png](attachment:image.png)

# %% [markdown]
# The eggs are these objects
# ![image.png](attachment:image.png)

# %% [markdown]
# 'Ghotul' can perform the following actions
# - Ghotul.move() : Moves 1 step in the direction it is facing.
# - Ghotul.turn_left() : Turns left in the same location as it is currently in.
# - Ghotul.pick_egg() : Ghotul picks up an egg provided it is on the location where the egg is.
# - Ghotul.drop_egg()  : Ghotul drops an egg at the location it is currently located at.

# %% [markdown]
# The following conditions can be used for moving Ghotul around
# - Ghotul.right_wall() : checks if Ghotul has reached  the right wall of the grid
# - Ghotul.left_wall()  :  checks if Ghotul has reached the left wall of the grid
# - Ghotul.bottom_wall() : checks if Ghotul has reached the bottom wall of the grid
# - Ghotul.top_wall() : checks if Ghotul has reached the top wall of the grid
# - Ghotul.front_is_clear() : checks if front is clear of eggs or a boundary wall

# %%
#start your code from here , you can add code in additional cells if necessary

# %% [markdown]
# # Steeple Chase
# Write code for Ghotul to cross each of the columns and collect the eggs to reach the right wall. The grid should look something like this after your code has executed
# ![image.png](attachment:image.png)

# %%
#run this cell once and also everytime when resetting the grid. 
import importlib
import lib
importlib.reload(lib)
from lib import *

token_loc=[[2,3,0,1],[2,3,1,2],[2,3,2,3],[4,5,0,1],
          [5,6,0,1],[5,6,1,2],[5,6,2,3],[5,6,3,4],[5,6,4,5],[5,6,5,6], [5,6,6,7],[5,6,7,8],
          [16,17,0,1],[16,17,1,2], [16,17,2,3],[16,17,3,4],[16,17,4,5],[13,14,0,1],
          [11,12,0,1],[11,12,1,2],[11,12,2,3],[11,12,3,4],[11,12,4,5],[11,12,5,6], [11,12,6,7],[9,10,0,1]]
Ghotul=None
Ghotul=bot(token_loc,20,20)
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
#start your code from here , you can add code in additional cells if necessary
